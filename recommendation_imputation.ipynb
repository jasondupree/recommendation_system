# %% [markdown]
# # **Sales Data Imputation System**

# %% [markdown]
# # **Milestone 1**

# %% [markdown]
# # **Recommendation System Imputation: Sales Data Example**
#
# --------------
# ## **Context**
# --------------
#
# Data integity issues in Point-of-Sale (POS) data continues to be an issue for large companies, providing opportunity for advanced imputation methods like leveraging recommendation systems.
#
# ----------------
# ## **Objective**
# ----------------
#
# Build a recommendation system to recommend (impute) sales for customers entirely or partially without POS data.
#
# -----------------------------
# ## **Dataset**
# -----------------------------
#
# The generic sales_data dataset contains the following attributes:
#
# - **Order Number:** Every order identified with a unique order-line id
# - **Order Line Number:** Every order identified with a unique order-line id
# - **Price Per Unit:** The rating of the corresponding product by the corresponding user
# - **Order Date:** Time of the rating. We **will not use this column** to solve the current problem
# - **Status:** Order status of the product.

# %% [markdown]
# ### **Importing Libraries and the Dataset**

# %%
#Mounting the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np 
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns 

from sklearn.metrics.pairwise import cosine_similarity 
from collections import defaultdict

from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import LabelEncoder

# %%
#importing the datasets
pos_df = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/sales_data.csv', encoding= 'unicode_escape')
bookings_df = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/bookings_data.csv')

# %% [markdown]
# ### **Reviewing the Data**

# %%
# See top 10 records of pos_df data
pos_df.head(10)
# Out:
#    ORDERNUMBER  ORDERLINENUMBER  PRICEEACH        ORDERDATE   STATUS  QTR_ID  \
# 0        10134                2      94.74    7/1/2003 0:00  Shipped       3
# 1        10145                6      83.26   8/25/2003 0:00  Shipped       3
# 2        10159               14     100.00  10/10/2003 0:00  Shipped       4
# 3        10168                1      96.66  10/28/2003 0:00  Shipped       4
# 4        10180                9      86.13  11/11/2003 0:00  Shipped       4
# 5        10188                1     100.00  11/18/2003 0:00  Shipped       4
# 6        10201                2      98.57   12/1/2003 0:00  Shipped       4
# 7        10211               14     100.00   1/15/2004 0:00  Shipped       1
# 8        10223                1     100.00   2/20/2004 0:00  Shipped       1
# 9        10237                7     100.00    4/5/2004 0:00  Shipped       2
#
#    MONTH_ID  YEAR_ID  PRODUCTLINE  MSRP  ...           CITY     STATE  \
# 0         7     2003  Motorcycles    95  ...          Paris       NaN
# 1         8     2003  Motorcycles    95  ...       Pasadena        CA
# 2        10     2003  Motorcycles    95  ...  San Francisco        CA
# 3        10     2003  Motorcycles    95  ...     Burlingame        CA
# 4        11     2003  Motorcycles    95  ...          Lille       NaN
# 5        11     2003  Motorcycles    95  ...         Bergen       NaN
# 6        12     2003  Motorcycles    95  ...  San Francisco        CA
# 7         1     2004  Motorcycles    95  ...          Paris       NaN
# 8         2     2004  Motorcycles    95  ...      Melbourne  Victoria
# 9         4     2004  Motorcycles    95  ...            NYC        NY
#
#   POSTALCODE    COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE  \
# 0      75508     France      EMEA        Da Cunha           Daniel   Medium
# 1      90003        USA       NaN           Young            Julie   Medium
# 2        NaN        USA       NaN           Brown            Julie   Medium
# 3      94217        USA       NaN          Hirano             Juri   Medium
# 4      59000     France      EMEA           Rance          Martine    Small
# 5     N 5804     Norway      EMEA          Oeztan           Veysel   Medium
# 6        NaN        USA       NaN          Murphy            Julie    Small
# 7      75016     France      EMEA         Perrier        Dominique   Medium
# 8       3004  Australia      APAC        Ferguson            Peter   Medium
# 9      10022        USA       NaN           Frick          Michael    Small
#
#   QUANTITYORDERED    SALES
# 0            41.0  3884.34
# 1            45.0  3746.70
# 2            49.0  5205.27
# 3            36.0  3479.76
# 4            29.0  2497.77
# 5            48.0  5512.32
# 6            22.0  2168.54
# 7            41.0  4708.44
# 8            37.0  3965.66
# 9            23.0  2333.12
#
# [10 rows x 25 columns]

# %%
# See top 10 records of bookings_df data
bookings_df.head(10)
# Out:
#   BOOKINGSORDERDATE BOOKINGSSTATUS PRODUCTCODE                CUSTOMERNAME  \
# 0     7/1/2003 0:00        Shipped    S10_1678             Lyon Souveniers
# 1    8/25/2003 0:00        Shipped    S10_1678           Toys4GrownUps.com
# 2   10/10/2003 0:00        Shipped    S10_1678    Corporate Gift Ideas Co.
# 3   10/28/2003 0:00        Shipped    S10_1678        Technics Stores Inc.
# 4   11/11/2003 0:00        Shipped    S10_1678    Daedalus Designs Imports
# 5   11/18/2003 0:00        Shipped    S10_1678                Herkku Gifts
# 6    12/1/2003 0:00        Shipped    S10_1678             Mini Wheels Co.
# 7    1/15/2004 0:00        Shipped    S10_1678            Auto Canal Petit
# 8    2/20/2004 0:00        Shipped    S10_1678  Australian Collectors, Co.
# 9     4/5/2004 0:00        Shipped    S10_1678             Vitachrome Inc.
#
#   BOOKINGSCOUNTRY BOOKINGSTERRITORY  BOOKINGSQUANTITYORDERED
# 0          France              EMEA                   7768.0
# 1             USA               NaN                   7492.0
# 2             USA               NaN                  10410.0
# 3             USA               NaN                   6958.0
# 4          France              EMEA                   4994.0
# 5          Norway              EMEA                  11024.0
# 6             USA               NaN                   4336.0
# 7          France              EMEA                   9416.0
# 8       Australia              APAC                   7930.0
# 9             USA               NaN                   4666.0

# %% [markdown]
# ### **Info Types + Description**

# %%
# See the info of the bookings_df data
pos_df.info()
pos_df.describe().T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2836 entries, 0 to 2835
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2836 non-null   int64
#  1   ORDERLINENUMBER   2836 non-null   int64
#  2   PRICEEACH         2817 non-null   float64
#  3   ORDERDATE         2836 non-null   object
#  4   STATUS            2836 non-null   object
#  5   QTR_ID            2836 non-null   int64
#  6   MONTH_ID          2836 non-null   int64
#  7   YEAR_ID           2836 non-null   int64
#  8   PRODUCTLINE       2836 non-null   object
#  9   MSRP              2836 non-null   int64
#  10  PRODUCTCODE       2836 non-null   object
#  11  CUSTOMERNAME      2836 non-null   object
#  12  PHONE             2836 non-null   object
#  13  ADDRESSLINE1      2836 non-null   object
#  14  ADDRESSLINE2      305 non-null    object
#  15  CITY              2836 non-null   object
#  16  STATE             1343 non-null   object
#  17  POSTALCODE        2758 non-null   object
#  18  COUNTRY           2836 non-null   object
#  19  TERRITORY         1758 non-null   object
#  20  CONTACTLASTNAME   2836 non-null   object
#  21  CONTACTFIRSTNAME  2836 non-null   object
#  22  DEALSIZE          2836 non-null   object
#  23  QUANTITYORDERED   2817 non-null   float64
#  24  SALES             2817 non-null   float64
# dtypes: float64(3), int64(6), object(16)
# memory usage: 554.0+ KB
#                   count          mean          std       min       25%  \
# ORDERNUMBER      2836.0  10261.253879    96.661615  10100.00  10180.00
# ORDERLINENUMBER  2836.0      6.467207     4.229732      1.00      3.00
# PRICEEACH        2817.0     83.631885    20.185024     26.88     68.78
# QTR_ID           2836.0      2.721086     1.202933      1.00      2.00
# MONTH_ID         2836.0      7.101904     3.654359      1.00      4.00
# YEAR_ID          2836.0   2003.814528     0.698813   2003.00   2003.00
# MSRP             2836.0    100.605783    40.017339     33.00     68.00
# QUANTITYORDERED  2817.0     35.104011     9.743597      6.00     27.00
# SALES            2817.0   3552.627497  1842.489205    482.13   2202.48
#
#                       50%      75%      max
# ORDERNUMBER      10263.00  10336.0  10788.0
# ORDERLINENUMBER      6.00      9.0     18.0
# PRICEEACH           95.55    100.0    100.0
# QTR_ID               3.00      4.0      4.0
# MONTH_ID             8.00     11.0     12.0
# YEAR_ID           2004.00   2004.0   2005.0
# MSRP                99.00    124.0    214.0
# QUANTITYORDERED     35.00     43.0     97.0
# SALES             3184.80   4508.0  14082.8

# %%
# See the info of the pos_df data
pos_df.info()
pos_df.describe().T
# print(pos_df.nunique())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2836 entries, 0 to 2835
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2836 non-null   int64
#  1   ORDERLINENUMBER   2836 non-null   int64
#  2   PRICEEACH         2817 non-null   float64
#  3   ORDERDATE         2836 non-null   object
#  4   STATUS            2836 non-null   object
#  5   QTR_ID            2836 non-null   int64
#  6   MONTH_ID          2836 non-null   int64
#  7   YEAR_ID           2836 non-null   int64
#  8   PRODUCTLINE       2836 non-null   object
#  9   MSRP              2836 non-null   int64
#  10  PRODUCTCODE       2836 non-null   object
#  11  CUSTOMERNAME      2836 non-null   object
#  12  PHONE             2836 non-null   object
#  13  ADDRESSLINE1      2836 non-null   object
#  14  ADDRESSLINE2      305 non-null    object
#  15  CITY              2836 non-null   object
#  16  STATE             1343 non-null   object
#  17  POSTALCODE        2758 non-null   object
#  18  COUNTRY           2836 non-null   object
#  19  TERRITORY         1758 non-null   object
#  20  CONTACTLASTNAME   2836 non-null   object
#  21  CONTACTFIRSTNAME  2836 non-null   object
#  22  DEALSIZE          2836 non-null   object
#  23  QUANTITYORDERED   2817 non-null   float64
#  24  SALES             2817 non-null   float64
# dtypes: float64(3), int64(6), object(16)
# memory usage: 554.0+ KB
#                   count          mean          std       min       25%  \
# ORDERNUMBER      2836.0  10261.253879    96.661615  10100.00  10180.00
# ORDERLINENUMBER  2836.0      6.467207     4.229732      1.00      3.00
# PRICEEACH        2817.0     83.631885    20.185024     26.88     68.78
# QTR_ID           2836.0      2.721086     1.202933      1.00      2.00
# MONTH_ID         2836.0      7.101904     3.654359      1.00      4.00
# YEAR_ID          2836.0   2003.814528     0.698813   2003.00   2003.00
# MSRP             2836.0    100.605783    40.017339     33.00     68.00
# QUANTITYORDERED  2817.0     35.104011     9.743597      6.00     27.00
# SALES            2817.0   3552.627497  1842.489205    482.13   2202.48
#
#                       50%      75%      max
# ORDERNUMBER      10263.00  10336.0  10788.0
# ORDERLINENUMBER      6.00      9.0     18.0
# PRICEEACH           95.55    100.0    100.0
# QTR_ID               3.00      4.0      4.0
# MONTH_ID             8.00     11.0     12.0
# YEAR_ID           2004.00   2004.0   2005.0
# MSRP                99.00    124.0    214.0
# QUANTITYORDERED     35.00     43.0     97.0
# SALES             3184.80   4508.0  14082.8

# %%
# Left merge the bookings_df and pos_df data on 'PRODUCTCODE' and 'CUSTOMERNAME'.
df = pd.merge(bookings_df, pos_df, how='left', on=['PRODUCTCODE', 'CUSTOMERNAME'])

# %%
df.head()
# Out:
#   BOOKINGSORDERDATE BOOKINGSSTATUS PRODUCTCODE              CUSTOMERNAME  \
# 0     7/1/2003 0:00        Shipped    S10_1678           Lyon Souveniers
# 1     7/1/2003 0:00        Shipped    S10_1678           Lyon Souveniers
# 2    8/25/2003 0:00        Shipped    S10_1678         Toys4GrownUps.com
# 3    8/25/2003 0:00        Shipped    S10_1678         Toys4GrownUps.com
# 4   10/10/2003 0:00        Shipped    S10_1678  Corporate Gift Ideas Co.
#
#   BOOKINGSCOUNTRY BOOKINGSTERRITORY  BOOKINGSQUANTITYORDERED  ORDERNUMBER  \
# 0          France              EMEA                   7768.0        10134
# 1          France              EMEA                   7768.0        10465
# 2             USA               NaN                   7492.0        10145
# 3             USA               NaN                   7492.0        10482
# 4             USA               NaN                  10410.0        10159
#
#    ORDERLINENUMBER  PRICEEACH  ...           CITY STATE  POSTALCODE  COUNTRY  \
# 0                2      94.74  ...          Paris   NaN       75508   France
# 1                2        NaN  ...          Paris   NaN       75508   France
# 2                6      83.26  ...       Pasadena    CA       90003      USA
# 3                6        NaN  ...       Pasadena    CA       90003      USA
# 4               14     100.00  ...  San Francisco    CA         NaN      USA
#
#    TERRITORY CONTACTLASTNAME  CONTACTFIRSTNAME DEALSIZE QUANTITYORDERED  \
# 0       EMEA        Da Cunha            Daniel   Medium            41.0
# 1       EMEA        Da Cunha            Daniel   Medium             NaN
# 2        NaN           Young             Julie   Medium            45.0
# 3        NaN           Young             Julie   Medium             NaN
# 4        NaN           Brown             Julie   Medium            49.0
#
#      SALES
# 0  3884.34
# 1      NaN
# 2  3746.70
# 3      NaN
# 4  5205.27
#
# [5 rows x 30 columns]
